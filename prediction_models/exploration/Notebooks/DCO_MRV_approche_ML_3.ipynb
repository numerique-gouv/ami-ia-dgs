# %% [markdown]
# #  Inférence de la variable DCO à partir des données de MRV (Stratégie ML conclusion )
# ## OPTUNA, SVM
#
# Rappel : La variable DCO représente le nom des dispositifs.Il y en a 1500 de différents et notre objectif est d'identifier le dispositif impliqué dans l'incident à partir de deux variables:
# - DESCRIPTION DE L'INCIDENT
# - LIBELLE COMMERCIAL
# - FABRICANT
# - REFERENCE
#
# Ce notebook conclu le premier Batch de l'approche machine learning pour le DCO. La stratégie est la suivante :
# - Netoyage des collones textuelles selon clean_text.py
# - Sélection des classes avec plus de 15 occurences
# - Séparation en train test avec 0,20 dans le test en en évitant que les doublons ne soient séparés.
# - Utilisation de 4 collones de texte : DESCRIPTION DE L'INCIDENT, LIBELLE COMMERCIAL, FABRICANT et  REFERENCE.
# - Encodage de ces 5 colonnes en tfidf
# - FineTunning des paramètres des tfidf avec la librairie Optuna
# - Application du SVM calibré (cf approche 1.1)
#
# ## 0) Chargement des librairies

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd



import clean_text

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GroupShuffleSplit
from sklearn.pipeline import Pipeline

from sklearn.metrics import confusion_matrix, accuracy_score, balanced_accuracy_score,f1_score
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import TfidfVectorizer,HashingVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.calibration import CalibratedClassifierCV
import spacy
nlp =spacy.load('fr')
from spacy.lang.fr.stop_words import STOP_WORDS

import joblib
import xgboost as xgb

import optuna
from optuna import Trial

from sklearn.svm import LinearSVC, SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, balanced_accuracy_score,f1_score

# %% [markdown]
# ## 1) Chargement des données et constructions du jeux d'évaluation
# On met de coté environ 20% du dataset pour l'évaluation et on ne garde pour l'entrainement seulement les classes avec plus de 10 observations

# %%
# %%time
df_declaration_mrv = pd.read_csv("data/data_mrv/declaration_mrv_complet.csv")#delimiter=';',encoding='ISO-8859-1')
id_to_dco = pd.read_csv("data/ref_MRV/referentiel_dispositif.csv",delimiter=';',encoding='ISO-8859-1')

#Charegement des colonnes utiles
df = df_declaration_mrv[['DESCRIPTION_INCIDENT','TYPE_VIGILANCE','LIBELLE_COMMERCIAL',
                         'REFERENCE_COMMERCIALE','ETAT_PATIENT','FABRICANT','DCO_ID','CLASSIFICATION']]
# On complète les NaN avec du vide
df['ETAT_PATIENT'] = df['ETAT_PATIENT'].fillna("")
df['DESCRIPTION_INCIDENT'] = df['DESCRIPTION_INCIDENT'].fillna("")
df['LIBELLE_COMMERCIAL'] = df['LIBELLE_COMMERCIAL'].fillna("")
df['FABRICANT'] = df['FABRICANT'].fillna("")
df["REFERENCE_COMMERCIALE"] = df['REFERENCE_COMMERCIALE'].fillna("")
df['TYPE_VIGILANCE'] = df['TYPE_VIGILANCE'].fillna("")
df['CLASSIFICATION'] = df['CLASSIFICATION'].fillna('')


# On ajoute des collones pertinentes
df['des_lib'] = df['LIBELLE_COMMERCIAL']+ ' ' + df['DESCRIPTION_INCIDENT']
df['fab_lib'] = df['LIBELLE_COMMERCIAL']+ ' ' + df['FABRICANT']
df['com'] = df['LIBELLE_COMMERCIAL']+ ' ' + df['REFERENCE_COMMERCIALE']
df['Text'] = df['LIBELLE_COMMERCIAL']+ ' ' + df['FABRICANT'] + "" + df['DESCRIPTION_INCIDENT']

# On nettoie les données :
for col in  ['DESCRIPTION_INCIDENT','LIBELLE_COMMERCIAL','ETAT_PATIENT','Text',"des_lib","fab_lib"] :
    df[col] = df[col].map(lambda x: clean_text.preprocess_text(x))

n = 15
# On filtre pour a voir plus de n observations par classse
df_n = df.groupby("DCO_ID").filter(lambda x: len(x) > n)

# On encode les labels
le = LabelEncoder()
df_n.DCO_ID = le.fit_transform(df_n.DCO_ID.values)
#On encode le type de vigilance
df_n.TYPE_VIGILANCE = le.fit_transform(df_n.TYPE_VIGILANCE.values)
#On encode la classifcation 
df_n.CLASSIFICATION = le.fit_transform(df_n.CLASSIFICATION.values)

# On selection les variables de test en faisant attention aux doublons
train_index,test_index = next(GroupShuffleSplit(random_state=1029).split(df_n, groups=df_n['DESCRIPTION_INCIDENT']))
df_train, df_test = df_n.iloc[train_index], df_n.iloc[test_index]
# Out:
# CPU times: user 38.6 s, sys: 380 ms, total: 39 s
# Wall time: 39 s

# %% [markdown]
# ## 2) Construction du pipeline

# %%
# %%time
#Pipeline
preprocess = ColumnTransformer(
    [('reference_tfidf', TfidfVectorizer(sublinear_tf=True, stop_words=STOP_WORDS), 'REFERENCE_COMMERCIALE'),
     
     ('libelle_tfidf', TfidfVectorizer(sublinear_tf=True, stop_words=STOP_WORDS), 'LIBELLE_COMMERCIAL'),
     
     ('description_tfidf',TfidfVectorizer(sublinear_tf=True,
                            stop_words=STOP_WORDS), 'DESCRIPTION_INCIDENT'),
     
    ('fabricant_tfidf',TfidfVectorizer(sublinear_tf=True, stop_words=STOP_WORDS), 'FABRICANT')],
    
    remainder='passthrough')


pipeline = Pipeline([
    ('vect', preprocess),
    ('clf', LinearSVC(class_weight='balanced')),
])

X = df_train[['DESCRIPTION_INCIDENT','FABRICANT','REFERENCE_COMMERCIALE','LIBELLE_COMMERCIAL']] # 
y = df_train.DCO_ID
# Out:
# CPU times: user 32 ms, sys: 4 ms, total: 36 ms
# Wall time: 32.3 ms

# %% [markdown]
# ## 2.1) Optimisation des paramètres de TFIDF

# %%
def objective(trial):    
    
    joblib.dump(study, 'study.pkl')
    train_index,test_index = next(GroupShuffleSplit(random_state=1029).split(X, groups=X['DESCRIPTION_INCIDENT']))
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    #reference
    vect__reference_tfidf__analyzer = trial.suggest_categorical('vect__reference_tfidf__analyzer', ['word', 'char', 'char_wb']) 
    vect__reference_tfidf__max_features = trial.suggest_int('vect__reference_tfidf__max_features', 500, 10_000)
    vect__reference_tfidf__min_df =  trial.suggest_int('vect__reference_tfidf__min_df', 1,5)
    vect__reference_tfidf__norm = trial.suggest_categorical('vect__reference_tfidf__norm', ('l1', 'l2'))
    #Description
    #vect__description_tfidf__analyzer = trial.suggest_categorical('vect__description_tfidf__analyzer', ['word', 'char', 'char_wb']) 
    vect__description_tfidf__max_features = trial.suggest_int('vect__description_tfidf__max_features', 1500, 60_000)
    vect__description_tfidf__min_df =  trial.suggest_int('vect__description_tfidf__min_df', 1,5)
    vect__description_tfidf__norm = trial.suggest_categorical('vect__description_tfidf__norm', ('l1', 'l2'))
    #Fabricant
    vect__fabricant_tfidf__analyzer = trial.suggest_categorical('vect__fabricant_tfidf__analyzer', ['word', 'char', 'char_wb']) 
    vect__fabricant_tfidf__max_features = trial.suggest_int('vect__fabricant_tfidf__max_features', 500, 10_000)
    vect__fabricant_tfidf__min_df =  trial.suggest_int('vect__fabricant_tfidf__min_df', 1,5)
    vect__fabricant_tfidf__norm = trial.suggest_categorical('vect__fabricant_tfidf__norm', ('l1', 'l2'))
    #Libelle
    vect__libelle_tfidf__analyzer = trial.suggest_categorical('vect__libelle_tfidf__analyzer', ['word', 'char', 'char_wb']) 
    vect__libelle_tfidf__max_features = trial.suggest_int('vect__libelle_tfidf__max_features', 500, 10_000)
    vect__libelle_tfidf__min_df =  trial.suggest_int('vect__libelle_tfidf__min_df', 1,5)
    vect__libelle_tfidf__norm = trial.suggest_categorical('vect__libelle_tfidf__norm', ('l1', 'l2'))
    
    #clf__C =trial.suggest_loguniform('svr_c', 1e-5, 1e5)
    

    
    params = {
        'vect__reference_tfidf__analyzer':vect__reference_tfidf__analyzer,
        'vect__reference_tfidf__max_features': vect__reference_tfidf__max_features,
        'vect__reference_tfidf__min_df':vect__reference_tfidf__min_df,
        'vect__reference_tfidf__norm':vect__reference_tfidf__norm,
        
        #'vect__description_tfidf__analyzer':vect__description_tfidf__analyzer,
        'vect__description_tfidf__max_features': vect__description_tfidf__max_features,
        'vect__description_tfidf__min_df':vect__description_tfidf__min_df,
        'vect__description_tfidf__norm':vect__description_tfidf__norm,
        
        'vect__fabricant_tfidf__analyzer':vect__fabricant_tfidf__analyzer,
        'vect__fabricant_tfidf__max_features': vect__fabricant_tfidf__max_features,
        'vect__fabricant_tfidf__min_df':vect__fabricant_tfidf__min_df,
        'vect__fabricant_tfidf__norm':vect__fabricant_tfidf__norm,
        
        'vect__libelle_tfidf__analyzer':vect__libelle_tfidf__analyzer,
        'vect__libelle_tfidf__max_features': vect__libelle_tfidf__max_features,
        'vect__libelle_tfidf__min_df':vect__libelle_tfidf__min_df,
        'vect__libelle_tfidf__norm':vect__libelle_tfidf__norm,
        
        #'clf__C':clf__C
    }
    
    pipeline.set_params(**params)
    pipeline.fit(X_train,y_train)
    y_pred = pipeline.predict(X_test)
    
    return balanced_accuracy_score(y_pred,y_test)

# %%
time_out = 75*100
studyName = 'optimisation_svm'
study = optuna.create_study(direction="maximize")
study.optimize(objective, timeout=time_out)

#Suvegarde du resultat
df = study.trials_dataframe()
df.to_json(studyName+'.json')
print(study.best_trial)
# Out:
# [I 2020-06-04 12:06:58,511] Finished trial#0 with value: 0.6724148828271783 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 4443, 'vect__reference_tfidf__min_df': 5, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 28242, 'vect__description_tfidf__min_df': 4, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 2136, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 4872, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#0 with value: 0.6724148828271783.
# [I 2020-06-04 12:08:48,248] Finished trial#1 with value: 0.6492288202679524 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 3899, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 15500, 'vect__description_tfidf__min_df': 4, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 8398, 'vect__fabricant_tfidf__min_df': 4, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 3811, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#0 with value: 0.6724148828271783.
# [I 2020-06-04 12:09:57,818] Finished trial#2 with value: 0.6624251493997563 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 778, 'vect__reference_tfidf__min_df': 5, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 27494, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 2802, 'vect__fabricant_tfidf__min_df': 5, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char_wb', 'vect__libelle_tfidf__max_features': 1860, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#0 with value: 0.6724148828271783.
# [I 2020-06-04 12:11:02,043] Finished trial#3 with value: 0.6762972466238514 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 564, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 25196, 'vect__description_tfidf__min_df': 4, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 4948, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 3774, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#3 with value: 0.6762972466238514.
# [I 2020-06-04 12:12:24,113] Finished trial#4 with value: 0.6361970479614883 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 3552, 'vect__reference_tfidf__min_df': 5, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 37191, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 6522, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 3357, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#3 with value: 0.6762972466238514.
# [I 2020-06-04 12:13:30,684] Finished trial#5 with value: 0.5975805190796429 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 3890, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 6812, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 1555, 'vect__fabricant_tfidf__min_df': 4, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 7224, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#3 with value: 0.6762972466238514.
# [I 2020-06-04 12:14:54,460] Finished trial#6 with value: 0.6429251834404576 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 2729, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 20141, 'vect__description_tfidf__min_df': 4, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 5091, 'vect__fabricant_tfidf__min_df': 4, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 6923, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#3 with value: 0.6762972466238514.
# [I 2020-06-04 12:16:11,687] Finished trial#7 with value: 0.6520172153892453 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 6961, 'vect__reference_tfidf__min_df': 5, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 23239, 'vect__description_tfidf__min_df': 4, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 3397, 'vect__fabricant_tfidf__min_df': 4, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char_wb', 'vect__libelle_tfidf__max_features': 4115, 'vect__libelle_tfidf__min_df': 5, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#3 with value: 0.6762972466238514.
# [I 2020-06-04 12:17:38,424] Finished trial#8 with value: 0.6555761287536848 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 9129, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 52878, 'vect__description_tfidf__min_df': 4, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 8990, 'vect__fabricant_tfidf__min_df': 4, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char_wb', 'vect__libelle_tfidf__max_features': 4826, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#3 with value: 0.6762972466238514.
# [I 2020-06-04 12:19:17,139] Finished trial#9 with value: 0.5281987557725989 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 4073, 'vect__reference_tfidf__min_df': 1, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 37400, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 7145, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char_wb', 'vect__libelle_tfidf__max_features': 2987, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#3 with value: 0.6762972466238514.
# [I 2020-06-04 12:20:27,245] Finished trial#10 with value: 0.6911978411220102 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 613, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 55923, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 4709, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 9737, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#10 with value: 0.6911978411220102.
# [I 2020-06-04 12:21:47,547] Finished trial#11 with value: 0.6911978411220102 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 576, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 59087, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 4563, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 9624, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#10 with value: 0.6911978411220102.
# [I 2020-06-04 12:23:03,513] Finished trial#12 with value: 0.6912736212977608 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 1705, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 59272, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 4259, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 9615, 'vect__libelle_tfidf__min_df': 5, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#12 with value: 0.6912736212977608.
# [I 2020-06-04 12:24:12,159] Finished trial#13 with value: 0.6873544287480624 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 1855, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 50502, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 3618, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 9853, 'vect__libelle_tfidf__min_df': 5, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#12 with value: 0.6912736212977608.
# [I 2020-06-04 12:25:19,717] Finished trial#14 with value: 0.6860862319844767 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 6535, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 59575, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 602, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 8437, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#12 with value: 0.6912736212977608.
# [I 2020-06-04 12:26:28,890] Finished trial#15 with value: 0.6911978411220102 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 1913, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 47682, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 6417, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 8432, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#12 with value: 0.6912736212977608.
# [I 2020-06-04 12:27:37,535] Finished trial#16 with value: 0.7477286015454442 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 2050, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 43687, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 4041, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6796, 'vect__libelle_tfidf__min_df': 5, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#16 with value: 0.7477286015454442.
# [I 2020-06-04 12:28:55,031] Finished trial#17 with value: 0.6580028177768843 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 1654, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 43241, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 3908, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6370, 'vect__libelle_tfidf__min_df': 5, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#16 with value: 0.7477286015454442.
# [I 2020-06-04 12:30:07,908] Finished trial#18 with value: 0.7477286015454442 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 5193, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 42246, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 6104, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6013, 'vect__libelle_tfidf__min_df': 5, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#16 with value: 0.7477286015454442.
# [I 2020-06-04 12:31:24,561] Finished trial#19 with value: 0.7559812429018207 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 5907, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 36996, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 7549, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5950, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:32:40,698] Finished trial#20 with value: 0.7514405368206183 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 7166, 'vect__reference_tfidf__min_df': 1, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 34355, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 7597, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8001, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:33:45,438] Finished trial#21 with value: 0.7514405368206183 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 5929, 'vect__reference_tfidf__min_df': 1, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 33436, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 7748, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5843, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:34:52,354] Finished trial#22 with value: 0.7514405368206183 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 7138, 'vect__reference_tfidf__min_df': 1, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 33826, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 7868, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 7889, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:35:59,404] Finished trial#23 with value: 0.7522607100369172 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 8168, 'vect__reference_tfidf__min_df': 1, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 34072, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 9993, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 7968, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:37:06,512] Finished trial#24 with value: 0.7495374864035099 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 8572, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 32092, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 9779, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5825, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:38:13,669] Finished trial#25 with value: 0.7522607100369172 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 7919, 'vect__reference_tfidf__min_df': 1, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 39215, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 9639, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8005, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:39:34,109] Finished trial#26 with value: 0.7356187463816132 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7958, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 40357, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 9948, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 7547, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:40:45,672] Finished trial#27 with value: 0.6999529725570084 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9942, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 17977, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 9137, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9051, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:41:49,621] Finished trial#28 with value: 0.7550405724577792 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9957, 'vect__reference_tfidf__min_df': 1, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 48097, 'vect__description_tfidf__min_df': 5, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 9215, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l1', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8750, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#19 with value: 0.7559812429018207.
# [I 2020-06-04 12:42:54,373] Finished trial#29 with value: 0.7581662042632822 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9934, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 47689, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 9057, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5035, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:43:58,733] Finished trial#30 with value: 0.7581662042632822 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9964, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 47187, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8585, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 4673, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:45:08,995] Finished trial#31 with value: 0.7581662042632822 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9659, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 45559, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8616, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 4849, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:46:23,968] Finished trial#32 with value: 0.7581662042632822 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9389, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 46520, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8411, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5161, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:47:37,052] Finished trial#33 with value: 0.7581662042632822 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9317, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 46220, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8375, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 4948, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:48:48,228] Finished trial#34 with value: 0.7372772307370995 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9337, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 53837, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8399, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 4508, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:50:14,104] Finished trial#35 with value: 0.7014145353333386 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9861, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 51222, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 8688, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 2264, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:51:48,945] Finished trial#36 with value: 0.5941777886756 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 9118, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 45193, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8147, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 617, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:53:13,557] Finished trial#37 with value: 0.7336920890132166 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 8562, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 46186, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 6964, 'vect__fabricant_tfidf__min_df': 5, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 3476, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:54:33,033] Finished trial#38 with value: 0.7487452078647239 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9430, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 27942, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 6000, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5368, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:56:01,929] Finished trial#39 with value: 0.6408641580420854 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 8544, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 54617, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 5611, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char_wb', 'vect__libelle_tfidf__max_features': 4335, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:57:09,279] Finished trial#40 with value: 0.7577090821560769 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9940, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 49168, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 9211, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5336, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:58:12,177] Finished trial#41 with value: 0.7581662042632822 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9514, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 40887, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8364, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 4931, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 12:59:15,592] Finished trial#42 with value: 0.7476862598957736 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 8971, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 40012, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 8392, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 3960, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 13:00:20,463] Finished trial#43 with value: 0.7581662042632822 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9645, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 56024, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 7101, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 4967, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 13:01:20,856] Finished trial#44 with value: 0.7318969150373301 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 9377, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 55920, 'vect__description_tfidf__min_df': 3, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 7163, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 2684, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 13:02:47,339] Finished trial#45 with value: 0.6589034927344714 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 8931, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 45661, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 8749, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char_wb', 'vect__libelle_tfidf__max_features': 4530, 'vect__libelle_tfidf__min_df': 3, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 13:03:57,688] Finished trial#46 with value: 0.6703755046801299 with parameters: {'vect__reference_tfidf__analyzer': 'char_wb', 'vect__reference_tfidf__max_features': 7549, 'vect__reference_tfidf__min_df': 2, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 51847, 'vect__description_tfidf__min_df': 2, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'word', 'vect__fabricant_tfidf__max_features': 6843, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 3547, 'vect__libelle_tfidf__min_df': 4, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#29 with value: 0.7581662042632822.
# [I 2020-06-04 13:05:27,343] Finished trial#47 with value: 0.7583045862392764 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 8450, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 58079, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 7934, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5254, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#47 with value: 0.7583045862392764.
# [I 2020-06-04 13:06:49,246] Finished trial#48 with value: 0.7410293082227913 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 8710, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 57251, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 8021, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6488, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l1'}. Best is trial#47 with value: 0.7583045862392764.
# [I 2020-06-04 13:08:22,190] Finished trial#49 with value: 0.6986729545888041 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7761, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 49985, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 7463, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char_wb', 'vect__libelle_tfidf__max_features': 5089, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#47 with value: 0.7583045862392764.
# [I 2020-06-04 13:09:54,085] Finished trial#50 with value: 0.7586286341376479 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 9493, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 57807, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6537, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5506, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#50 with value: 0.7586286341376479.
# [I 2020-06-04 13:11:20,973] Finished trial#51 with value: 0.7608748395085875 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 8288, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 57345, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6548, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5675, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:12:44,266] Finished trial#52 with value: 0.7590541680874744 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 8293, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 57502, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 5491, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5637, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:13:53,269] Finished trial#53 with value: 0.7473538050802304 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6635, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 10160, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 5637, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5460, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:15:12,775] Finished trial#54 with value: 0.7582435609601038 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7404, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 59394, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6424, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6278, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:16:38,874] Finished trial#55 with value: 0.7577835280012301 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 8325, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 59170, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 5322, 'vect__fabricant_tfidf__min_df': 1, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6862, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:18:05,826] Finished trial#56 with value: 0.759524716552169 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7531, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 57823, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6184, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6274, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:19:30,993] Finished trial#57 with value: 0.7573445714854194 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7438, 'vect__reference_tfidf__min_df': 3, 'vect__reference_tfidf__norm': 'l2', 'vect__description_tfidf__max_features': 57281, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6707, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6426, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:20:58,008] Finished trial#58 with value: 0.758570972977557 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6564, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 59861, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6393, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 7272, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:22:16,969] Finished trial#59 with value: 0.6856562597983308 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6140, 'vect__reference_tfidf__min_df': 5, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 53091, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6005, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'char', 'vect__libelle_tfidf__max_features': 7306, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:23:49,470] Finished trial#60 with value: 0.6718056644127447 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6924, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 57847, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 4819, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 5633, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:25:12,070] Finished trial#61 with value: 0.7590910645220259 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7494, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 59345, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6345, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6179, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:26:37,525] Finished trial#62 with value: 0.7573906722348048 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5106, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 54498, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 5456, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 6089, 'vect__libelle_tfidf__min_df': 2, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# [I 2020-06-04 13:28:05,985] Finished trial#63 with value: 0.7595345565144359 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 8180, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 58275, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 6260, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 7226, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#51 with value: 0.7608748395085875.
# ...
# [I 2020-06-04 13:48:57,697] Finished trial#79 with value: 0.7505335983435293 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5720, 'vect__reference_tfidf__min_df': 5, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 15787, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 1955, 'vect__fabricant_tfidf__min_df': 3, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 7634, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#75 with value: 0.7613835985416003.
# [I 2020-06-04 13:50:21,769] Finished trial#80 with value: 0.7619791923717949 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7195, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 19815, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3101, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8268, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#80 with value: 0.7619791923717949.
# [I 2020-06-04 13:51:38,060] Finished trial#81 with value: 0.7571190649189833 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 7254, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 29860, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 2609, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8367, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#80 with value: 0.7619791923717949.
# [I 2020-06-04 13:52:53,517] Finished trial#82 with value: 0.7610955592479863 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6767, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 20712, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3072, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9204, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#80 with value: 0.7619791923717949.
# [I 2020-06-04 13:54:11,939] Finished trial#83 with value: 0.7627880040582791 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6754, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 20508, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3008, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8719, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#83 with value: 0.7627880040582791.
# [I 2020-06-04 13:55:32,688] Finished trial#84 with value: 0.7640688193512893 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6747, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 20469, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3178, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8930, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 13:56:50,924] Finished trial#85 with value: 0.7622441220330605 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5499, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 20273, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3137, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9313, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 13:58:18,514] Finished trial#86 with value: 0.7044958697445048 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5409, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 20560, 'vect__description_tfidf__min_df': 4, 'vect__description_tfidf__norm': 'l1', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3107, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9316, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 13:59:43,920] Finished trial#87 with value: 0.7549443599474974 with parameters: {'vect__reference_tfidf__analyzer': 'char', 'vect__reference_tfidf__max_features': 4535, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 18521, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 2498, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9970, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 14:01:01,356] Finished trial#88 with value: 0.7548150377757676 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6860, 'vect__reference_tfidf__min_df': 5, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 12186, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3878, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9011, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 14:02:23,437] Finished trial#89 with value: 0.762776528074806 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6297, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 22146, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3183, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8643, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 14:03:41,280] Finished trial#90 with value: 0.7597361980054625 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6154, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 15697, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 1910, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9454, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 14:05:01,664] Finished trial#91 with value: 0.7592269876026958 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6739, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 21469, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3147, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 9008, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 14:06:20,542] Finished trial#92 with value: 0.7640072762581738 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6331, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 18390, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char_wb', 'vect__fabricant_tfidf__max_features': 3332, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8566, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#84 with value: 0.7640688193512893.
# [I 2020-06-04 14:07:42,528] Finished trial#93 with value: 0.7652523543400792 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6387, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 18248, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 2755, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8671, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#93 with value: 0.7652523543400792.
# [I 2020-06-04 14:08:55,861] Finished trial#94 with value: 0.7652673563667555 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 6359, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 18194, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 2827, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8687, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#94 with value: 0.7652673563667555.
# [I 2020-06-04 14:10:18,294] Finished trial#95 with value: 0.7652911910054219 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5805, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 18294, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 2387, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8655, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#95 with value: 0.7652911910054219.
# [I 2020-06-04 14:11:31,956] Finished trial#96 with value: 0.765175498828441 with parameters: {'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5774, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 18310, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 1173, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8667, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}. Best is trial#95 with value: 0.7652911910054219.
# FrozenTrial(number=95, value=0.7652911910054219, datetime_start=datetime.datetime(2020, 6, 4, 14, 8, 55, 862307), datetime_complete=datetime.datetime(2020, 6, 4, 14, 10, 18, 293696), params={'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5805, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1', 'vect__description_tfidf__max_features': 18294, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 2387, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8655, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}, distributions={'vect__reference_tfidf__analyzer': CategoricalDistribution(choices=('word', 'char', 'char_wb')), 'vect__reference_tfidf__max_features': IntUniformDistribution(high=10000, low=500, step=1), 'vect__reference_tfidf__min_df': IntUniformDistribution(high=5, low=1, step=1), 'vect__reference_tfidf__norm': CategoricalDistribution(choices=('l1', 'l2')), 'vect__description_tfidf__max_features': IntUniformDistribution(high=60000, low=1500, step=1), 'vect__description_tfidf__min_df': IntUniformDistribution(high=5, low=1, step=1), 'vect__description_tfidf__norm': CategoricalDistribution(choices=('l1', 'l2')), 'vect__fabricant_tfidf__analyzer': CategoricalDistribution(choices=('word', 'char', 'char_wb')), 'vect__fabricant_tfidf__max_features': IntUniformDistribution(high=10000, low=500, step=1), 'vect__fabricant_tfidf__min_df': IntUniformDistribution(high=5, low=1, step=1), 'vect__fabricant_tfidf__norm': CategoricalDistribution(choices=('l1', 'l2')), 'vect__libelle_tfidf__analyzer': CategoricalDistribution(choices=('word', 'char', 'char_wb')), 'vect__libelle_tfidf__max_features': IntUniformDistribution(high=10000, low=500, step=1), 'vect__libelle_tfidf__min_df': IntUniformDistribution(high=5, low=1, step=1), 'vect__libelle_tfidf__norm': CategoricalDistribution(choices=('l1', 'l2'))}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=95, state=TrialState.COMPLETE)

# %% [markdown]
# ## Conclusion

# %%
params={'vect__reference_tfidf__analyzer': 'word', 'vect__reference_tfidf__max_features': 5805, 'vect__reference_tfidf__min_df': 4, 'vect__reference_tfidf__norm': 'l1',
        'vect__description_tfidf__max_features': 18294, 'vect__description_tfidf__min_df': 1, 'vect__description_tfidf__norm': 'l2', 
        'vect__fabricant_tfidf__analyzer': 'char', 'vect__fabricant_tfidf__max_features': 2387, 'vect__fabricant_tfidf__min_df': 2, 'vect__fabricant_tfidf__norm': 'l2', 
        'vect__libelle_tfidf__analyzer': 'word', 'vect__libelle_tfidf__max_features': 8655, 'vect__libelle_tfidf__min_df': 1, 'vect__libelle_tfidf__norm': 'l2'}

# %% [markdown]
# ## 3) Applicattion du SVM sur le jeu de test

# %%
# %%time
#Pipeline
preprocess = ColumnTransformer(
    [('reference_tfidf', TfidfVectorizer(sublinear_tf=True,
                                         analyzer='word',
                                         min_df=4,
                                         ngram_range=(1, 1),
                                         stop_words=STOP_WORDS,
                                         max_features = 5804,
                                         norm = 'l1'), 'REFERENCE_COMMERCIALE'),
     
     ('libelle_tfidf', TfidfVectorizer(sublinear_tf=True,
                                         analyzer='word',
                                         min_df=1,
                                         ngram_range=(1, 1),
                                         stop_words=STOP_WORDS,
                                         max_features = 8655,
                                         norm = 'l2'), 'LIBELLE_COMMERCIAL'),
     
     ('description_tfidf',TfidfVectorizer(sublinear_tf=True,
                                         min_df=1,
                                         ngram_range=(1, 1),
                                         stop_words=STOP_WORDS,
                                         max_features = 18294,
                                         norm = 'l2'), 'DESCRIPTION_INCIDENT'),
     
    ('fabricant_tfidf',TfidfVectorizer(sublinear_tf=True,
                                         analyzer='char',
                                         min_df=2,
                                         ngram_range=(1, 1),
                                         stop_words=STOP_WORDS,
                                         max_features = 2387,
                                         norm = 'l2'), 'FABRICANT')],
    
    remainder='passthrough')


pipeline = Pipeline([
    ('vect', preprocess),
    ('clf', CalibratedClassifierCV(LinearSVC(class_weight='balanced'),cv=5, method='isotonic')),
])

X = df_train[['DESCRIPTION_INCIDENT','FABRICANT','REFERENCE_COMMERCIALE','LIBELLE_COMMERCIAL']] # 
y = df_train.DCO_ID


pipeline.fit(X,y)
X_test = df_test[['DESCRIPTION_INCIDENT','FABRICANT','REFERENCE_COMMERCIALE','LIBELLE_COMMERCIAL']]
y_test = df_test.DCO_ID

y_pred = pipeline.predict(X_test)

print("Justesse", accuracy_score(y_test,y_pred) )
print("Balanced_accuracy : ", balanced_accuracy_score(y_test,y_pred))
print("f1-weighted : ", f1_score(y_test, y_pred, average='weighted'))
# Out:
# précison: 0.8467366372419546
# Balanced_accuracy :  0.7248460354275542
# f1-weighted :  0.8332177155633408
# CPU times: user 8min 46s, sys: 5.48 s, total: 8min 51s
# Wall time: 8min 51s
