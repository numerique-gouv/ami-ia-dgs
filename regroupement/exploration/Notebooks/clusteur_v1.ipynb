# %%
import pandas as pd
import gensim
import pyLDAvis
import pyLDAvis.gensim
import os
import sklearn as sk 
import json

import sys
sys.path.insert(0,"/home/robin/Nextcloud/strar_clay/GitLab/signalement-ia/regroupement/exploration/Scripts/")
import utils

SAVE_PATH =  "/home/robin/Nextcloud/strar_clay/GitLab/Annexe/L3/"


# Loading
topicmodel = utils.TopicModel()
topicmodel.load(SAVE_PATH,'rake_tri')

# %%
import pandas as pd
SAVE_PATH = "/home/robin/Nextcloud/strar_clay/GitLab/Annexe/L3/"

df_test = pd.read_pickle(os.path.join(SAVE_PATH,'cleaned_data.pkl'),encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-74b720b878fd> in <module>
#       2 SAVE_PATH = "/home/robin/Nextcloud/strar_clay/GitLab/Annexe/L3/"
#       3
# ----> 4 df_test = pd.read_pickle(os.path.join(SAVE_PATH,'cleaned_data.pkl'),encoding='latin1')
#
# TypeError: read_pickle() got an unexpected keyword argument 'encoding'

# %%
from utils import ClusteurModel
model = ClusteurModel()
model.topicmodel = topicmodel
model.n_clusteur = 150
model.train()

# %%
model.save("/home/robin/Nextcloud/strar_clay/GitLab/Annexe/L3/kmeans.sav")
# Out:
# /home/robin/.local/lib/python3.6/site-packages/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /home/robin/.local/lib/python3.6/site-packages/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))

# %%
import sklearn
X = sklearn.metrics.pairwise_distances(model.model.cluster_centers_, metric = 'cosine')

# %%
X.shape
# Out:
# (150, 150)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(18, 14))
data = ax.imshow(X, cmap='RdBu_r', origin='lower')
plt.title('')
plt.colorbar(data)
